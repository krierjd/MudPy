# %% [markdown]
# ### Make the faulty geometry that is going to be used in FakeQuakes
#
# We're going to start with a planar geometry

# %%
import sys
sys.path.append('/Users/dmelgarm/code/MudPy/src/python')
from mudpy import forward

# %%
#Parameters of hte fault grometry

fout = '/Users/dmelgarm/Seattle_fault/Geometries/planar.fault'
strike = 90  # south dipping east-west strike
dip = 40
nstrike = 30 
dx_dip = 2.0 # in km
dx_strike = 2.0 # in km
center_of_fault = [-122.402, 47.579, 5.0] # lon, lat, depth (km)
num_updip = 3
num_downdip = 3
rise_time = 2.0

# %%
forward.makefault(fout,strike,dip,nstrike,dx_dip,dx_strike,center_of_fault,num_updip,num_downdip,rise_time)
# Out:
# Hi

# %%
from mudpy import view

# %%
view.slip3D('/Users/dmelgarm/FakeQuakes/Seattle_fault/output/ruptures/planar1.000127.rupt')
